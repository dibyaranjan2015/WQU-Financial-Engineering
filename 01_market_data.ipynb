# %%
# Install the financial data library right inside the notebook
# %pip install yfinance pandas matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 3.5 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 3.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 3.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 3.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 3.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 3.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [yfinance]/19 [yfinance]]]-py]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Fetch historical stock data for a specific ticker symbol
ticker = 'AAPL'  # Example: Apple Inc.
data = yf.download(ticker, start='2020-01-01', end='2026-07-01')

# Display the first few rows of the data
print(data.head())

#Display the last few rows of the data
print(data.tail())

#Plot the closing price over time
data['Close'].plot(figsize=(10, 5), title=f'{ticker} Closing Price')
plt.ylabel('Price (USD)')
plt.xlabel('Date')
plt.show()
#plt.grid()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.333862  72.394070  71.091169  71.344039  135480400
# 2020-01-03  71.630630  72.389250  71.406659  71.563198  146322800
# 2020-01-06  72.201401  72.239935  70.503539  70.754006  118387200
# 2020-01-07  71.861847  72.466330  71.642689  72.211049  108872000
# 2020-01-08  73.017830  73.318870  71.565614  71.565614  132079200
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2026-06-24  293.079987  299.700012  292.940002  295.359985   53081900
# 2026-06-25  275.149994  288.799988  273.750000  287.399994  107013700
# 2026-06-26  283.779999  285.950012  274.209991  275.000000  261775500
# 2026-06-29  281.739990  288.369995  279.850006  286.730011   66427000
# ...
